# %% [markdown]
# # Classifying emotions from model RoBERTa

# %% [markdown]
# ## __Initializing model__

# %% [markdown]
# ### __Model trained on GoEmotions (Dataset from Google)__
#
# __What emotions are we talking about ?__
#
# admiration, amusement, anger, annoyance, approval, caring,
# confusion, curiosity, desire, disappointment, disapproval,
# disgust, embarrassment, excitement, fear, gratitude, grief,
# joy, love, nervousness, optimism, pride, realization, relief,
# remorse, sadness, surprise + neutral

# %%
# Imports
from transformers import pipeline

# %%
# Initializing model 
emotion_classifier_go = pipeline(
    'text-classification',
    model='SamLowe/roberta-base-go_emotions',
    top_k=4
)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: SamLowe/roberta-base-go_emotions
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Trying it out

response = emotion_classifier_go("I watched him go with a sinking feeling in my stomach")
response
# Out:
# [[{'label': 'sadness', 'score': 0.5851103663444519},
#   {'label': 'disappointment', 'score': 0.10608816146850586},
#   {'label': 'nervousness', 'score': 0.09969314932823181},
#   {'label': 'fear', 'score': 0.08060894906520844}]]

# %% [markdown]
# ### __Alternative model__
#
# __What emotions are we talking about ?__
#
# anger 🤬, disgust 🤢, fear 😨, joy 😀, neutral 😐, sadness 😭, surprise 😲

# %%
# Initializing model

emotion_classifier_simple = pipeline("text-classification", 
                      model="j-hartmann/emotion-english-distilroberta-base", 
                      top_k=4)
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: j-hartmann/emotion-english-distilroberta-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Trying it out

response = emotion_classifier_simple("Wow, this is really beautiful")
print(response)
# Out:
# [[{'label': 'surprise', 'score': 0.9604347348213196}, {'label': 'joy', 'score': 0.019467052072286606}, {'label': 'neutral', 'score': 0.00813004095107317}, {'label': 'fear', 'score': 0.004241007845848799}]]
